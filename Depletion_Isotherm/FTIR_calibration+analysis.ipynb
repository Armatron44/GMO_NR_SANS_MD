# %%
import uncertainties
from uncertainties import ufloat
import numpy as np

# %%
#concentration of master solution for GMO standards between 8 mmol and 20 mmol.
GMO_RMM = 356.547 # g mol-1

Mass_GMO = ufloat(0.3075, 0.00005) #g
Volume_GMO = ufloat(0.010, (0.05/1000)) #dm-3
stockconc = (Mass_GMO/GMO_RMM)/Volume_GMO #mol dm-3

print(stockconc)
# Out:
# 0.0862+/-0.0004

# %%
# use a function to find the concentration of solutions after dilution stock solution.

def conc_after_dilution(stock_M, dod_M, stock_conc):
    dod_dens = ufloat(0.747, 0.003) #density of dodecane @ 25 deg C
    stock_dens = ufloat(0.745, 0.005) #measured in lab
    conc = (((stock_M/stock_dens)*stock_conc)/((stock_M/stock_dens)+(dod_M/dod_dens)))
    return conc

# %%
# lets find concentrations given mass of stock and neat dodecane.

A5_stock_mass = ufloat(0.7010, 0.00005) # g
A5_dod_mass = ufloat(2.162, 0.00005) # g
A5_conc = conc_after_dilution(A5_stock_mass, A5_dod_mass, stockconc)

A6_stock_mass = ufloat(0.7077, 0.00005) 
A6_dod_mass = ufloat(2.3284, 0.00005)
A6_conc = conc_after_dilution(A6_stock_mass, A6_dod_mass, stockconc)

A7_stock_mass = ufloat(0.7052, 0.00005) 
A7_dod_mass = ufloat(2.3058, 0.00005)
A7_conc = conc_after_dilution(A7_stock_mass, A7_dod_mass, stockconc)

print(A5_conc)
print(A6_conc)
print(A7_conc)
# Out:
# 0.02116+/-0.00016
# 0.02014+/-0.00016
# 0.02024+/-0.00016

# %%
B5_stock_mass = ufloat(0.5959, 0.00005) 
B5_dod_mass = ufloat(2.4032, 0.00005)
B5_conc = conc_after_dilution(B5_stock_mass, B5_dod_mass, stockconc)
B6_stock_mass = ufloat(0.5987, 0.00005) 
B6_dod_mass = ufloat(2.4286, 0.00005)
B6_conc = conc_after_dilution(B6_stock_mass, B6_dod_mass, stockconc)
B7_stock_mass = ufloat(0.6016, 0.00005) 
B7_dod_mass = ufloat(2.4018, 0.00005)
B7_conc = conc_after_dilution(B7_stock_mass, B7_dod_mass, stockconc)

print(B5_conc)
print(B6_conc)
print(B7_conc)
# Out:
# 0.01717+/-0.00014
# 0.01709+/-0.00014
# 0.01731+/-0.00014

# %%
C5_stock_mass = ufloat(0.4985, 0.00005) 
C5_dod_mass = ufloat(2.5183, 0.00005)
C5_conc = conc_after_dilution(C5_stock_mass, C5_dod_mass, stockconc)
C6_stock_mass = ufloat(0.5032, 0.00005) 
C6_dod_mass = ufloat(2.5110, 0.00005)
C6_conc = conc_after_dilution(C6_stock_mass, C6_dod_mass, stockconc)
C7_stock_mass = ufloat(0.4971, 0.00005) 
C7_dod_mass = ufloat(2.5098, 0.00005)
C7_conc = conc_after_dilution(C7_stock_mass, C7_dod_mass, stockconc)

print(C5_conc)
print(C6_conc)
print(C7_conc)
# Out:
# 0.01428+/-0.00012
# 0.01443+/-0.00012
# 0.01429+/-0.00012

# %%
D5_stock_mass = ufloat(0.4008, 0.00005) 
D5_dod_mass = ufloat(2.6010, 0.00005)
D5_conc = conc_after_dilution(D5_stock_mass, D5_dod_mass, stockconc)
D6_stock_mass = ufloat(0.4189, 0.00005) 
D6_dod_mass = ufloat(2.6378, 0.00005)
D6_conc = conc_after_dilution(D6_stock_mass, D6_dod_mass, stockconc)
D7_stock_mass = ufloat(0.3926, 0.00005) 
D7_dod_mass = ufloat(2.6158, 0.00005)
D7_conc = conc_after_dilution(D7_stock_mass, D7_dod_mass, stockconc)

print(D5_conc)
print(D6_conc)
print(D7_conc)
# Out:
# 0.01154+/-0.00010
# 0.01185+/-0.00010
# 0.01128+/-0.00010

# %%
E5_stock_mass = ufloat(0.2976, 0.00005) 
E5_dod_mass = ufloat(2.7002, 0.00005)
E5_conc = conc_after_dilution(E5_stock_mass, E5_dod_mass, stockconc)
E6_stock_mass = ufloat(0.2933, 0.00005) 
E6_dod_mass = ufloat(2.7214, 0.00005)
E6_conc = conc_after_dilution(E6_stock_mass, E6_dod_mass, stockconc)
E7_stock_mass = ufloat(0.2980, 0.00005) 
E7_dod_mass = ufloat(2.7022, 0.00005)
E7_conc = conc_after_dilution(E7_stock_mass, E7_dod_mass, stockconc)

print(E5_conc)
print(E6_conc)
print(E7_conc)
# Out:
# 0.00858+/-0.00007
# 0.00841+/-0.00007
# 0.00859+/-0.00007

# %%
### lower concentrations

#concentration of stock solutions (two were used)

Mass_GMO_lower = ufloat(0.2972, 0.00005) #g
Volume_GMO_lower = ufloat(0.1, (0.1/1000)) #dm-3
stockconc_lower = (Mass_GMO_lower/GMO_RMM)/Volume_GMO_lower
print(stockconc_lower)

Mass_GMO_lower2 = ufloat(0.2021, 0.00005) #g
Volume_GMO_lower2 = ufloat(0.1, (0.1/1000)) #dm-3
stockconc_lower2 = (Mass_GMO_lower2/GMO_RMM)/Volume_GMO_lower2
print(stockconc_lower2)
# Out:
# 0.008336+/-0.000008
# 0.005668+/-0.000006

# %%
F5_stock_mass, G5_stock_mass, H5_stock_mass, I5_stock_mass, J5_stock_mass, K5_stock_mass, L5_stock_mass, M5_stock_mass, N5_stock_mass = [
    ufloat(5.0434, 0.00005), ufloat(4.3156, 0.00005), ufloat(2.1562, 0.00005), ufloat(1.0721, 0.00005), 
    ufloat(0.5381, 0.00005), ufloat(0.3599, 0.00005), ufloat(0.2742, 0.00005), ufloat(0.1788, 0.00005),
    ufloat(0.0893, 0.00005)]

F5_dod_mass, G5_dod_mass, H5_dod_mass, I5_dod_mass, J5_dod_mass, K5_dod_mass, L5_dod_mass, M5_dod_mass, N5_dod_mass = [
    ufloat(2.4546, 0.00005), ufloat(3.1842, 0.00005), ufloat(5.3439, 0.00005), ufloat(6.4191, 0.00005), 
    ufloat(6.9518, 0.00005), ufloat(7.1462, 0.00005), ufloat(7.2245, 0.00005), ufloat(7.3113, 0.00005),
    ufloat(7.4041, 0.00005)]

G6_stock_mass, H6_stock_mass, I6_stock_mass, J6_stock_mass, K6_stock_mass, L6_stock_mass, M6_stock_mass, N6_stock_mass = [
    ufloat(6.4319, 0.00005), ufloat(3.2148, 0.00005), ufloat(1.6095, 0.00005), ufloat(0.8136, 0.00005), 
    ufloat(0.5327, 0.00005), ufloat(0.4118, 0.00005), ufloat(0.2690, 0.00005), ufloat(0.1359, 0.00005)]

G6_dod_mass, H6_dod_mass, I6_dod_mass, J6_dod_mass, K6_dod_mass, L6_dod_mass, M6_dod_mass, N6_dod_mass = [
    ufloat(1.0753, 0.00005), ufloat(4.2818, 0.00005), ufloat(5.8886, 0.00005), ufloat(6.6828, 0.00005), 
    ufloat(6.9526, 0.00005), ufloat(7.0887, 0.00005), ufloat(7.2231, 0.00005), ufloat(7.3569, 0.00005)]

G7_stock_mass, H7_stock_mass, I7_stock_mass, J7_stock_mass, K7_stock_mass, L7_stock_mass, M7_stock_mass, N7_stock_mass = [
    ufloat(6.4311, 0.00005), ufloat(3.2127, 0.00005), ufloat(1.6056, 0.00005), ufloat(0.8043, 0.00005), 
    ufloat(0.5361, 0.00005), ufloat(0.4009, 0.00005), ufloat(0.2660, 0.00005), ufloat(0.1339, 0.00005)]

G7_dod_mass, H7_dod_mass, I7_dod_mass, J7_dod_mass, K7_dod_mass, L7_dod_mass, M7_dod_mass, N7_dod_mass = [
    ufloat(1.0721, 0.00005), ufloat(4.2819, 0.00005), ufloat(5.8917, 0.00005), ufloat(6.6893, 0.00005), 
    ufloat(6.9505, 0.00005), ufloat(7.0879, 0.00005), ufloat(7.2280, 0.00005), ufloat(7.3542, 0.00005)]

F5_conc = conc_after_dilution(F5_stock_mass, F5_dod_mass, stockconc_lower)
G5_conc = conc_after_dilution(G5_stock_mass, G5_dod_mass, stockconc_lower)
H5_conc = conc_after_dilution(H5_stock_mass, H5_dod_mass, stockconc_lower)
I5_conc = conc_after_dilution(I5_stock_mass, I5_dod_mass, stockconc_lower)
J5_conc = conc_after_dilution(J5_stock_mass, J5_dod_mass, stockconc_lower)
K5_conc = conc_after_dilution(K5_stock_mass, K5_dod_mass, stockconc_lower)
L5_conc = conc_after_dilution(L5_stock_mass, L5_dod_mass, stockconc_lower)
M5_conc = conc_after_dilution(M5_stock_mass, M5_dod_mass, stockconc_lower)
N5_conc = conc_after_dilution(N5_stock_mass, N5_dod_mass, stockconc_lower)

G6_conc = conc_after_dilution(G6_stock_mass, G6_dod_mass, stockconc_lower2)
H6_conc = conc_after_dilution(H6_stock_mass, H6_dod_mass, stockconc_lower2)
I6_conc = conc_after_dilution(I6_stock_mass, I6_dod_mass, stockconc_lower2)
J6_conc = conc_after_dilution(J6_stock_mass, J6_dod_mass, stockconc_lower2)
K6_conc = conc_after_dilution(K6_stock_mass, K6_dod_mass, stockconc_lower2)
L6_conc = conc_after_dilution(L6_stock_mass, L6_dod_mass, stockconc_lower2)
M6_conc = conc_after_dilution(M6_stock_mass, M6_dod_mass, stockconc_lower2)
N6_conc = conc_after_dilution(N6_stock_mass, N6_dod_mass, stockconc_lower2)

G7_conc = conc_after_dilution(G7_stock_mass, G7_dod_mass, stockconc_lower2)
H7_conc = conc_after_dilution(H7_stock_mass, H7_dod_mass, stockconc_lower2)
I7_conc = conc_after_dilution(I7_stock_mass, I7_dod_mass, stockconc_lower2)
J7_conc = conc_after_dilution(J7_stock_mass, J7_dod_mass, stockconc_lower2)
K7_conc = conc_after_dilution(K7_stock_mass, K7_dod_mass, stockconc_lower2)
L7_conc = conc_after_dilution(L7_stock_mass, L7_dod_mass, stockconc_lower2)
M7_conc = conc_after_dilution(M7_stock_mass, M7_dod_mass, stockconc_lower2)
N7_conc = conc_after_dilution(N7_stock_mass, N7_dod_mass, stockconc_lower2)

# %%
# peak integration was done in originlab 2020, along with the regression
# using the Fit linear with x error option.

from IPython.core.display import SVG, display, Image
display(SVG(filename='Calibration_curve.svg'))
# Out:
# C:\Users\soo29949\AppData\Local\Temp\ipykernel_37696\2862531365.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import SVG, display, Image

# %%
#use regression line vairables

cov_matrix = np.array([0.00347059150256424, -0.250375720494716, -0.250375720494716, 40.1176158793027]).reshape(2, 2)
(c, m) = uncertainties.correlated_values([-0.0134934147249419, 1099.29227354918], cov_matrix)
print(c, m)
# Out:
# -0.01+/-0.06 1099+/-6

# %%
# now we want to use regression to find the concentration of depletion isotherm samples.

def find_conc_from_standards(c, m, area):
    conc = (area - c)/m
    return conc

def add_element(dict, key, value):
    if key not in dict:
        dict[key] = []
    dict[key].append(value)
    
def tot_vol(stock, dod):
    dod_dens = ufloat(0.747, 0.003)
    stock_dens = ufloat(0.745, 0.005)
    return (((stock/stock_dens)+(dod/dod_dens))/1000)

# %%
#peak integration was done in originlab 2020.
#input the areas, find the resulting concentrations after depletion & convert to a dictionary.
deg_30_PA = {'A30_area':3.40271979623409, 
'B30_area':2.25536375553775,
'C30_area':1.79002472262078,
'D30_area':1.36424789659793,
'E30_area':1.09940822705814,
'F30_area':0.78000568543263,
'G30_area':0.400106045777574,
'H30_area':0.295275154263874,
'I30_area':0.205739377409268}

deg_45_PA = {'A45_area':3.69020782080357, 
'B45_area':2.632782215056,
'C45_area':2.21354528167499,
'D45_area':1.8420254614008,
'E45_area':1.56981870144067,
'F45_area':1.09755390304268,
'G45_area':0.640710779659626,
'H45_area':0.489670841935475,
'I45_area':0.304109755164051}

deg_60_PA = {'A60_area':3.7864253653572, 
'B60_area':2.81310712640789,
'C60_area':2.38893133763834,
'D60_area':1.9311799756963,
'E60_area':1.52864607989953,
'F60_area':1.22951854776212,
'G60_area':0.678843167997296,
'H60_area':0.545466818784483,
'I60_area':0.362001025109549}

deg_70_PA = {'A70_area':3.35195537993762,
'B70_area':2.93466320429675,
'C70_area':2.3606473693954,
'D70_area':1.95348525084641,
'E70_area':1.55239279063268,
'F70_area':1.06330461203155,
'G70_area':0.855306442366417,
'H70_area':0.678298551333465,
'I70_area':0.497503996557005} 

deg_30_finalconc = {}
for i, k in deg_30_PA.items():
    add_element(deg_30_finalconc, i[0:3]+"_finalconc", find_conc_from_standards(c, m, k))
    
deg_45_finalconc = {}
for i, k in deg_45_PA.items():
    add_element(deg_45_finalconc, i[0:3]+"_finalconc", find_conc_from_standards(c, m, k))
    
deg_60_finalconc = {}
for i, k in deg_60_PA.items():
    add_element(deg_60_finalconc, i[0:3]+"_finalconc", find_conc_from_standards(c, m, k))
    
deg_70_finalconc = {}
for i, k in deg_70_PA.items():
    add_element(deg_70_finalconc, i[0:3]+"_finalconc", find_conc_from_standards(c, m, k))

# %%
def sol_ML(mass_list):
    masses = []
    for i in mass_list:
        masses.append(ufloat(i, 0.00005))
    return masses

# %%
# now we need to determine the initial concentration of the samples

#deg30
#inital concentration

Mass_GMO30 = ufloat(0.1362, 0.00005) #g
Volume_GMO30 = ufloat(0.020, (0.05/1000)) #dm-3
stockconc30 = (Mass_GMO30/GMO_RMM)/Volume_GMO30

# 11 samples in total.
stock_M_30_list = np.array([2.3475, 1.8725, 1.6928, 1.4941, 1.3219, 1.1212, 
                            0.8518, 0.7546, 0.6538])
stock_M_30 = np.array(sol_ML(stock_M_30_list))

dod_M_30_list = np.array([6.636, 7.1056, 7.3022, 7.4842, 7.6747, 7.8546, 
                          8.1531, 8.2443, 8.3211])
dod_M_30 = np.array(sol_ML(dod_M_30_list))

initconc_30 = []
for i, j in enumerate(stock_M_30):
    initconc_30.append(conc_after_dilution(j, dod_M_30[i], stockconc30))

lossconc_30 = []
for i, j in enumerate(np.array(initconc_30)):
    lossconc_30.append(j-list(deg_30_finalconc.items())[i][1][0])

# %%
#deg45
#inital concentration

Mass_GMO45 = ufloat(0.1307, 0.00005) #g
Volume_GMO45 = ufloat(0.020, (0.05/1000)) #dm-3
stockconc45 = (Mass_GMO45/GMO_RMM)/Volume_GMO45

# 12 samples in total.
stock_M_45_list = np.array([2.442, 1.9615, 1.7625, 1.5651, 
                            1.3738, 1.1800, 0.8854, 0.7905, 0.6864])
stock_M_45 = np.array(sol_ML(stock_M_45_list))

dod_M_45_list = np.array([6.5291, 7.0167, 7.2101, 7.4147, 
                          7.6149, 7.8031, 8.1113, 8.1911, 8.297])
dod_M_45 = np.array(sol_ML(dod_M_45_list))

initconc_45 = []
for i, j in enumerate(stock_M_45):
    initconc_45.append(conc_after_dilution(j, dod_M_45[i], stockconc45))

lossconc_45 = []
for i, j in enumerate(np.array(initconc_45)):
    lossconc_45.append(j-list(deg_45_finalconc.items())[i][1][0])

# %%
#deg60
#inital concentration

Mass_GMO60 = ufloat(0.135, 0.00005) #g
Volume_GMO60 = ufloat(0.020, (0.05/1000)) #dm-3
stockconc60 = (Mass_GMO60/GMO_RMM)/Volume_GMO60

# 11 samples in total

stock_M_60_list = np.array([2.3747, 1.9104, 1.7145, 1.5213, 1.3394, 1.1509, 0.858, 0.7649, 0.672])
stock_M_60 = np.array(sol_ML(stock_M_60_list))

dod_M_60_list = np.array([6.6122, 7.0708, 7.2737, 7.4715, 7.6567, 7.8508, 8.1403, 8.2304, 8.3307])
dod_M_60 = np.array(sol_ML(dod_M_60_list))

initconc_60 = []
for i, j in enumerate(stock_M_60):
    initconc_60.append(conc_after_dilution(j, dod_M_60[i], stockconc60))

lossconc_60 = []
for i, j in enumerate(np.array(initconc_60)):
    lossconc_60.append(j-list(deg_60_finalconc.items())[i][1][0])

# %%
#deg70
#inital concentration

Mass_GMO70 = ufloat(0.1306, 0.00005) #g
Volume_GMO70 = ufloat(0.020, (0.05/1000)) #dm-3
stockconc70 = (Mass_GMO70/GMO_RMM)/Volume_GMO70

# 12 samples in total

stock_M_70_list = np.array([1.9592, 1.7662, 1.5648, 1.3729, 1.1766, 0.8923, 0.7826, 0.6969, 0.5956, 0.491, 0.4892])
stock_M_70 = np.array(sol_ML(stock_M_70_list))

dod_M_70_list = np.array([7.0249, 7.2314, 7.4155, 7.6223, 7.8102, 8.1093, 8.2118, 8.322, 8.3955, 8.4913, 8.5128])
dod_M_70 = np.array(sol_ML(dod_M_70_list))

initconc_70 = []
for i, j in enumerate(stock_M_70):
    initconc_70.append(conc_after_dilution(j, dod_M_70[i], stockconc70))

lossconc_70 = []
for i, j in enumerate(np.array(initconc_70)[0:-2]):
    lossconc_70.append(j-list(deg_70_finalconc.items())[i][1][0])

# %%
# now we need to define the amount of FeOx in each sample

def FeOx_ML(mass_list):
    masses = []
    for i in mass_list:
        masses.append(ufloat(i, 0.00005))
    return masses

# %%
#BET surface areas and mass of iron oxide added

FeOx_30_mass_list = np.array([0.4957, 0.4947, 0.5295, 0.5347, 0.5165,
                              0.5182, 0.5132, 0.503, 0.4666])
FeOx_30_ML = FeOx_ML(FeOx_30_mass_list)

BET = ufloat(11.7756, 0.0937)

SA_30 = np.array(FeOx_30_ML)*BET

# %%
# 45 degc - BET surface areas and mass of iron oxide added

FeOx_45_mass_list = np.array([0.4938, 0.5063, 0.5149, 0.5057, 0.4955, 0.5093, 0.4959, 0.5009, 0.4833])
FeOx_45_ML = FeOx_ML(FeOx_45_mass_list)

SA_45 = np.array(FeOx_45_ML)*BET

# %%
FeOx_60_mass_list = np.array([0.5351, 0.5022, 0.5116, 0.5156, 0.5192, 0.4992, 0.4924, 0.4944, 0.5168])
FeOx_60_ML = FeOx_ML(FeOx_60_mass_list)

SA_60 = np.array(FeOx_60_ML)*BET

# %%
FeOx_70_mass_list = np.array([0.49, 0.5052, 0.5216, 0.513, 0.5041, 0.4881, 0.4934, 0.5113, 0.4923, 0.5061])
FeOx_70_ML = FeOx_ML(FeOx_70_mass_list)

SA_70 = np.array(FeOx_70_ML)*BET

# %%
# now we will find amount adsorbed at each temperature and save out the equilibrium concentration and amount adsorbed.
# the data will be saved out into txt files for loading into originlab.

# %%
#find amount adsorbed for 30 degree data.
AA_30 = []
for i, j in enumerate(lossconc_30):
    AA_30.append(j*tot_vol(stock_M_30[i], dod_M_30[i]))

AApA_30 = np.array(AA_30)/SA_30

#final lists
AApA_30_y = []
AApA_30_yerr = []
for i in AApA_30:
    AApA_30_y.append(i.nominal_value)
    AApA_30_yerr.append(i.std_dev)
x30list = []
xerr30list = []
for i, k in deg_30_finalconc.items():
    x30list.append(k[0].nominal_value)
    xerr30list.append(k[0].std_dev)
results_30 = np.array(x30list)
results_30a = np.stack((results_30, xerr30list, AApA_30_y, AApA_30_yerr))

print(results_30a.T)

np.savetxt("30final.txt", results_30a.T)
# Out:
# [[3.10764780e-03 4.36442427e-05 3.90338334e-06 1.16037476e-07]
#  [2.06392533e-03 4.64556090e-05 3.98017845e-06 1.15861760e-07]
#  [1.64061750e-03 4.77647701e-05 3.79035120e-06 1.08919230e-07]
#  [1.25329846e-03 4.90383433e-05 3.69012346e-06 1.07751301e-07]
#  [1.01238012e-03 4.98645104e-05 3.56662035e-06 1.10923002e-07]
#  [7.21827233e-04 5.08934204e-05 3.28876415e-06 1.09801493e-07]
#  [3.76241579e-04 5.21607637e-05 2.86291727e-06 1.10453608e-07]
#  [2.80879413e-04 5.25183859e-05 2.69478409e-06 1.12207344e-07]
#  [1.99430850e-04 5.28264382e-05 2.61446889e-06 1.20110254e-07]]

# %%
#find amount adsorbed for 45 degree data.
AA_45 = []
for i, j in enumerate(lossconc_45):
    AA_45.append(j*tot_vol(stock_M_45[i], dod_M_45[i]))

AApA_45 = np.array(AA_45)/SA_45

#final lists
AApA_45_y = []
AApA_45_yerr = []
for i in AApA_45:
    AApA_45_y.append(i.nominal_value)
    AApA_45_yerr.append(i.std_dev)
x45list = []
xerr45list = []
for i, k in deg_45_finalconc.items():
    x45list.append(k[0].nominal_value)
    xerr45list.append(k[0].std_dev)
results_45 = np.array(x45list)
results_45a = np.stack((results_45, xerr45list, AApA_45_y, AApA_45_yerr))

print(results_45a.T)

np.savetxt("45final.txt", results_45a.T)
# Out:
# [[3.36916880e-03 4.30428011e-05 3.36843742e-06 1.13597477e-07]
#  [2.40725392e-03 4.54622635e-05 3.23839755e-06 1.09833554e-07]
#  [2.02588406e-03 4.65695403e-05 3.13601650e-06 1.07738504e-07]
#  [1.68792133e-03 4.76140599e-05 3.05705595e-06 1.09381218e-07]
#  [1.44030132e-03 4.84147855e-05 2.82100732e-06 1.10761893e-07]
#  [1.01069328e-03 4.98703829e-05 2.81326881e-06 1.08816091e-07]
#  [5.95113975e-04 5.13527748e-05 2.50250097e-06 1.11738314e-07]
#  [4.57716541e-04 5.18578787e-05 2.36391182e-06 1.10602652e-07]
#  [2.88916039e-04 5.24881195e-05 2.35658744e-06 1.15116455e-07]]

# %%
#find amount adsorbed
AA_60 = []
for i, j in enumerate(lossconc_60):
    AA_60.append(j*tot_vol(stock_M_60[i], dod_M_60[i]))

AApA_60 = np.array(AA_60)/SA_60

#final lists
AApA_60_y = []
AApA_60_yerr = []
for i in AApA_60:
    AApA_60_y.append(i.nominal_value)
    AApA_60_yerr.append(i.std_dev)
x60list = []
xerr60list = []
for i, k in deg_60_finalconc.items():
    x60list.append(k[0].nominal_value)
    xerr60list.append(k[0].std_dev)
results_60 = np.array(x60list)
results_60a = np.stack((results_60, xerr60list, AApA_60_y, AApA_60_yerr))

print(results_60a.T)

np.savetxt("60final.txt", results_60a.T)
# Out:
# [[3.45669561e-03 4.28514583e-05 2.97231603e-06 1.04815885e-07]
#  [2.57129119e-03 4.50106166e-05 2.97847439e-06 1.09703451e-07]
#  [2.18542858e-03 4.60968087e-05 2.86479292e-06 1.07388067e-07]
#  [1.76902307e-03 4.73582037e-05 2.85800900e-06 1.06834234e-07]
#  [1.40284757e-03 4.85384005e-05 2.80263214e-06 1.06375247e-07]
#  [1.13073838e-03 4.94554874e-05 2.65643260e-06 1.10150113e-07]
#  [6.29802100e-04 5.12264003e-05 2.45150967e-06 1.12212740e-07]
#  [5.08472812e-04 5.16704496e-05 2.28671000e-06 1.11681227e-07]
#  [3.41578349e-04 5.22903710e-05 2.12945623e-06 1.07430470e-07]]

# %%
#find amount adsorbed
AA_70 = []
for i, j in enumerate(lossconc_70):
    AA_70.append(j*tot_vol(stock_M_70[i], dod_M_70[i]))

AApA_70 = np.array(AA_70)/SA_70[0:-1]

#final lists
AApA_70_y = []
AApA_70_yerr = []
for i in AApA_70:
    AApA_70_y.append(i.nominal_value)
    AApA_70_yerr.append(i.std_dev)
x70list = []
xerr70list = []
for i, k in deg_70_finalconc.items():
    x70list.append(k[0].nominal_value)
    xerr70list.append(k[0].std_dev)
results_70 = np.array(x70list)
results_70a = np.stack((results_70, xerr70list, AApA_70_y, AApA_70_yerr))

print(results_70a.T)

np.savetxt("70final.txt", results_70a.T)
# Out:
# [[3.06146862e-03 4.37549767e-05 1.96221014e-06 1.08009677e-07]
#  [2.68186786e-03 4.47148629e-05 1.86567313e-06 1.04456201e-07]
#  [2.15969933e-03 4.61721343e-05 2.03386004e-06 1.01848682e-07]
#  [1.78931365e-03 4.72946974e-05 2.01875817e-06 1.03800144e-07]
#  [1.42444939e-03 4.84670256e-05 1.98478017e-06 1.05848685e-07]
#  [9.79537519e-04 4.99790639e-05 1.76224086e-06 1.09727582e-07]
#  [7.90326538e-04 5.06477478e-05 1.67305472e-06 1.08935176e-07]
#  [6.29306675e-04 5.12282019e-05 1.58325990e-06 1.05944931e-07]
#  [4.64842175e-04 5.18315070e-05 1.56040143e-06 1.10249689e-07]]

# %%
display(SVG(filename='Individual_isotherms.svg'))

# %%
display(SVG(filename='Isotherm_overlay.svg'))

# %%
# calculate surface excess and area per molecule for each temperature
#30 deg
cov_matrix30 = np.array([8.66544743657359E-15, -7.78159613856941E-5, -7.78159613856941E-5, 976157.965831035]).reshape(2, 2)
(V, K) = uncertainties.correlated_values([4.15099981905515E-6, 6311.00258787803], cov_matrix30)
Na = 6.0221409e+23 
APM30 = (1/(V*Na))*1E20
print(APM30)
print(V, K)

#45 deg
cov_matrix45 = np.array([7.89848615917902E-15, -6.55685428348112E-5, -6.55685428348112E-5, 743704.979391142]).reshape(2, 2)
(V45, K45) = uncertainties.correlated_values([3.42892062407737E-6, 5061.96064537861], cov_matrix45) 
APM45 = (1/(V45*Na))*1E20
print(APM45)
print(V45, K45)

#60 deg
cov_matrix60 = np.array([6.61987781342271E-15, -7.43144902324181E-5, -7.43144902324181E-5, 1168847.84908236]).reshape(2, 2)
(V60, K60) = uncertainties.correlated_values([3.12880945151676E-6, 5704.11219941483], cov_matrix60) 
APM60 = (1/(V60*Na))*1E20
print(APM60)
print(V60, K60)

#70 deg
cov_matrix70 = np.array([7.37747569805022E-15, -1.11513740011939E-4, -1.11513740011939E-4, 2186667.94331342]).reshape(2, 2)
(V70, K70) = uncertainties.correlated_values([2.1327690188544E-6, 5324.85505253591], cov_matrix70) 
APM70 = (1/(V70*Na))*1E20
print(APM70)
print(V70, K70)
# Out:
# 40.0+/-0.9
# (4.15+/-0.09)e-06 (6.3+/-1.0)e+03
# 48.4+/-1.3
# (3.43+/-0.09)e-06 (5.1+/-0.9)e+03
# 53.1+/-1.4
# (3.13+/-0.08)e-06 (5.7+/-1.1)e+03
# 77.9+/-3.1
# (2.13+/-0.09)e-06 (5.3+/-1.5)e+03

# %%
import uncertainties.umath as ium

# need the log of K for Vant Hoff

print(repr(ium.log(K)))
print(repr(ium.log(K45)))
print(repr(ium.log(K60)))
print(repr(ium.log(K70)))
# Out:
# 8.750049831642471+/-0.15655310767907293
# 8.52950916655462+/-0.1703654717822256
# 8.648942632204816+/-0.18953565983873197
# 8.5801407700261+/-0.2777049549579562

# %%
### kl values that appear in the depletion isotherm table - we'll use these (includes rounding error...)

k_tab30 = ufloat(6300, 1000)
k_tab45 = ufloat(5100, 900)
k_tab60 = ufloat(5700, 1100)
k_tab70 = ufloat(5300, 1500)

print(repr(ium.log(k_tab30)))
print(repr(ium.log(k_tab45)))
print(repr(ium.log(k_tab60)))
print(repr(ium.log(k_tab70)))
# Out:
# 8.748304912379623+/-0.15873015873015872
# 8.536995818712418+/-0.1764705882352941
# 8.648221453822641+/-0.19298245614035087
# 8.575462099540212+/-0.2830188679245283

# %%
#display the rounding error regression.
display(Image(filename='Vant_Hoff.png'))

# %%
#vant hoff regression - with rounding error & scaling with chi2

cov_matrixVH = np.array([1.24670219101358, -396.412442140369, -396.412442140369, 126294.347699293]).reshape(2, 2)
(Scom, Hcom) = uncertainties.correlated_values([7.44148984187263, 383.001404368485], cov_matrixVH) 

DeltaS = Scom*8.3145

DeltaH = (-Hcom*8.3145)/1000 #kJ mol-1

print(f'{DeltaS:.1f}') # J K-1 mol-1
#positive delta S. Relates to a larger number of accessible states for the system upon adsorption.

print(f'{DeltaH:.1f}') # kJ mol-1 - weakly negative delta H.
# Out:
# 61.9+/-9.3
# -3.2+/-3.0

# %%
#vant hoff regression - without rounding error & scaling with chi2

cov_matrixVH = np.array([1.43120543438553, -455.157329804003, -455.157329804003, 145032.18019642]).reshape(2, 2)
(Scom, Hcom) = uncertainties.correlated_values([7.45248254176564, 378.821428745342], cov_matrixVH) 

DeltaS = Scom*8.3145

DeltaH = (-Hcom*8.3145)/1000 #kJ mol-1

print(f'{DeltaS:.1f}') # J K-1 mol-1
#positive delta S. Relates to a larger number of accessible states for the system upon adsorption.

print(f'{DeltaH:.1f}') # kJ mol-1 - weakly negative delta H.
# Out:
# 62.0+/-9.9
# -3.1+/-3.2
